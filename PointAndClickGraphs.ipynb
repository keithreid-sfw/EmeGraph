# %%
"""
MIT license
Dr Keith Reid 2024
Eme Graph
"""

import numpy as np
import matplotlib.pyplot as plt; plt.ion()
import networkx
import netgraph

# bit of magic
# %matplotlib notebook

# ask them what they care about
labels    = []
answer    = None
while answer != "STOP":
    answer = input("Please write something important to you or write STOP\t")
    labels.append(answer)
stop       = labels.pop()
node_count = len(labels)
labels     = zip(range(node_count), labels)

# make the graph
total_nodes             = node_count
weights                 = np.random.rand(total_nodes, total_nodes)
connection_probability  = 1
is_connected            = np.random.rand(total_nodes, total_nodes) <= connection_probability
graph                   = np.zeros((total_nodes, total_nodes))
graph[is_connected]     = weights[is_connected]
g                       = networkx.from_numpy_array(graph, networkx.DiGraph)

# make it so you can change it
pos                     = networkx.layout.spring_layout(g)
plot_instance           = netgraph.InteractiveGraph(graph, 
                                                    node_labels=True,                                         node_positions=pos)
# give them a key
for i in labels:
    print(i)
# Out:
# Please write something important to you or write STOP	Foo
# Please write something important to you or write STOP	Bar
# Please write something important to you or write STOP	Jam
# Please write something important to you or write STOP	Spam
# Please write something important to you or write STOP	Mandolorian
# Please write something important to you or write STOP	Coding
# Please write something important to you or write STOP	Linux
# Please write something important to you or write STOP	STOP
# <img src="data:image/png;base64,..." width="640">
# (0, 'Foo')
# (1, 'Bar')
# (2, 'Jam')
# (3, 'Spam')
# (4, 'Mandolorian')
# (5, 'Coding')
# (6, 'Linux')
# /home/user/.local/lib/python3.10/site-packages/netgraph/_utils.py:360: RuntimeWarning: invalid value encountered in true_divide
#   v = v / np.linalg.norm(v, axis=-1)[:, None] # unit vector
